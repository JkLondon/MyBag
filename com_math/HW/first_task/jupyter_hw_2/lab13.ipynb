# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('lab1_3.csv', delimiter=',')
data
# Out:
#     first_min, дел first_max, дел  zero, дел V_накала, V  дел_x, В  дел_y, mV  \
# 0              3.0           12,5       20.0       3,336       2.0       20.0
# 1              0.0           13,5       20.0        2,72       2.0        5.0
# 2              NaN            NaN        NaN         NaN       NaN        NaN
# 3              NaN            NaN        NaN         NaN       NaN        NaN
# 4              NaN            NaN        NaN         NaN       NaN        NaN
# 5              NaN            NaN        NaN         NaN       NaN        NaN
# 6              NaN            NaN        NaN         NaN       NaN        NaN
# 7              NaN            NaN        NaN         NaN       NaN        NaN
# 8              NaN            NaN        NaN         NaN       NaN        NaN
# 9              NaN            NaN        NaN         NaN       NaN        NaN
# 10             NaN            NaN        NaN         NaN       NaN        NaN
# ...

# %%
v_1 = np.array(data['V_k'])
i_1 = np.array(data['I_a'])

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import math

# %%
fig, ax = plt.subplots()
ax.scatter(x=v_1,y=i_1)
ax.set_title('ВАХ')
# Out:
# Text(0.5, 1.0, 'ВАХ')
